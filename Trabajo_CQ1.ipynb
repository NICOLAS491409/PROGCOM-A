# %% [markdown]
# <a href="https://colab.research.google.com/github/NICOLAS491409/PROGCOM-A/blob/main/Trabajo_CQ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Trabajo cq1.jpg](data:image/jpeg;base64,...)
